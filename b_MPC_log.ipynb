# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML, Image

# %%
import logging
import time
import numpy as np

import cflib.crtp
from cflib.crazyflie import Crazyflie
from cflib.crazyflie.syncCrazyflie import SyncCrazyflie
from cflib.crazyflie.log import LogConfig
from cflib.crazyflie.syncLogger import SyncLogger

URI = f'radio://0/1/2M'

# Only output errors from the logging framework
logging.basicConfig(level=logging.ERROR)

log_keys = ['result',
            'u0',
            'u1',
            'u2',
            'u3',]

other_log_keys = []

if __name__ == '__main__':
    cflib.crtp.init_drivers(enable_debug_driver=False)

    with SyncCrazyflie(URI, cf=Crazyflie(rw_cache='./cache')) as scf:
        cf = scf.cf

        lg_stab = LogConfig(name='MPC', period_in_ms=10)
        lg_data = {}

        for key in log_keys:
            lg_stab.add_variable('ctrlMPC.' + key, 'float')
            lg_data[key] = []

        for key in other_log_keys:
            lg_stab.add_variable( key, 'float')
            lg_data[key.split('.')[1]] = []

        cf.param.set_value('kalman.resetEstimation', '1')  # will reset all states
        time.sleep(0.1)
        cf.param.set_value('kalman.resetEstimation', '0')
        time.sleep(2)
        print('Reset Kalman filter.')
            
        print('Switching to MPC!')
        cf.param.set_value('stabilizer.controller', '1')
        time.sleep(0.1)
        print('Taking off!')
        for y in range(10):
            cf.commander.send_position_setpoint(0, 0, y / 20, 0)
            time.sleep(0.1)
        # cf.param.set_value('stabilizer.controller', '5')  # re-initialize after each (unresetted) run
        # time.sleep(0.1)
        
        cf.param.set_value('stabilizer.controller', '5')
        delta_max = 2.1
        with SyncLogger(scf, lg_stab) as logger:
            t_start = time.time()
            entry_count = 0

            for log_entry in logger:
                delta_t = time.time() - t_start

                if (delta_t < 0.3):
                    cf.commander.send_position_setpoint(0, 2.5, 0.5, 0)
                else:
                    cf.commander.send_position_setpoint(0, 0, 0.5, 0)
                for key, value in log_entry[1].items():
                    lg_data[key.split('.')[1]].append(value)

                entry_count += 1

                if delta_t > delta_max:  # x100 data points
                    break

        print('Saving data...')
        for key in lg_data.keys():
            lg_data[key] = np.array(lg_data[key])

        np.savez('quad_data/quad_traj', **lg_data)

        for y in range(9):
            cf.commander.send_position_setpoint(0, 0, (10 - y) / 20, 0)
            time.sleep(0.15)

        for i in range(10):
            cf.commander.send_stop_setpoint()
            time.sleep(0.1)

print('Done!')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 27
#      24 if __name__ == '__main__':
#      25     cflib.crtp.init_drivers(enable_debug_driver=False)
# ---> 27     with SyncCrazyflie(URI, cf=Crazyflie(rw_cache='./cache')) as scf:
#      28         cf = scf.cf
#      30         lg_stab = LogConfig(name='MPC', period_in_ms=10)
#
# File ~/.local/lib/python3.8/site-packages/cflib/crazyflie/syncCrazyflie.py:119, in SyncCrazyflie.__enter__(self)
#     118 def __enter__(self):
# --> 119     self.open_link()
#     120     return self
#
# File ~/.local/lib/python3.8/site-packages/cflib/crazyflie/syncCrazyflie.py:89, in SyncCrazyflie.open_link(self)
#      87 self._params_updated_event.clear()
#      88 self.cf.open_link(self._link_uri)
# ---> 89 self._connect_event.wait()
#      90 self._connect_event = None
#      92 if not self._is_link_open:
#
# File ~/miniconda3/envs/crazyflie/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/miniconda3/envs/crazyflie/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
import os
N = int(delta_max * 100) - 1
if os.path.isfile('quad_data/quad_traj.npz'):
    npzfile = np.load('quad_data/quad_traj.npz')

    plt.rcParams["figure.figsize"] = (16,8)
    fig = plt.figure()

    ax = fig.add_subplot(311, title='Controls')
    ax.plot(npzfile['u0'][:N], label='u0')
    ax.plot(npzfile['u1'][:N], label='u1')
    ax.plot(npzfile['u2'][:N], label='u2')
    ax.plot(npzfile['u3'][:N], label='u3')
    ax.legend()

    # ax = fig.add_subplot(312, title='Result')
    # result = np.zeros(N)
    # for i in range(N): 
    #     if (npzfile['result'][i] < 0):
    #         result[i] = 0
    #     else:
    #         result[i] = npzfile['result'][i]
    # ax.plot(result[:N])

    ax = fig.add_subplot(311, title='Time')
    ax.plot(npzfile['mpcTime'][:N], label='Time')

    # ax = fig.add_subplot(313, title='Moments')
    # ax.plot(npzfile['u2_pwm'][:125] / (2 ** 15), label='M1')
    # ax.plot(npzfile['u3_pwm'][:125] / (2 ** 15), label='M2')
    # ax.legend()
    
else:
    print('No flight data found.')
